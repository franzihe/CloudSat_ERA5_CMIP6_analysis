# %% [markdown]
# # Welcome to the interactive Galaxy IPython Notebook.

# %% [markdown]
# You can access your data via the dataset number. Using a Python kernel, you can access dataset number 42 with ``handle = open(get(42), 'r')``.
# To save data, write your data to a file, and then call ``put('filename.txt')``. The dataset will then be available in your galaxy history.
# <br>When using a non-Python kernel, ``get`` and ``put`` are available as command-line tools, which can be accessed using system calls in R, Julia, and Ruby. For example, to read dataset number 42 into R, you can write ```handle <- file(system('get -i 42', intern = TRUE))```.
# To save data in R, write the data to a file and then call ``system('put -p filename.txt')``.
# Notebooks can be saved to Galaxy by clicking the large green button at the top right of the IPython interface.<br>
# More help and informations can be found on the project [website](https://github.com/bgruening/docker-jupyter-notebook).

# %%
import xarray as xr
xr.set_options(display_style="html")
# %matplotlib inline

# %%
dset = xr.open_dataset("x.nc")

# %%
dset.time
# Out:
# <xarray.DataArray 'time' (time: 660)>
# array([cftime.DatetimeNoLeap(0001-02-01 00:00:00),
#        cftime.DatetimeNoLeap(0001-03-01 00:00:00),
#        cftime.DatetimeNoLeap(0001-04-01 00:00:00), ...,
#        cftime.DatetimeNoLeap(0055-11-01 00:00:00),
#        cftime.DatetimeNoLeap(0055-12-01 00:00:00),
#        cftime.DatetimeNoLeap(0056-01-01 00:00:00)], dtype=object)
# Coordinates:
#   * time     (time) object 0001-02-01 00:00:00 ... 0056-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bounds

# %% [markdown]
# # VEGETATION DEMOGRAPHY

# %% [markdown]
# ## AREA_TREES

# %%
dset['AREA_TREES'].plot(aspect=3, size=6)

# %% [markdown]
# ## AREA_PLANT

# %%
dset['AREA_PLANT'].plot(aspect=3, size=6)

# %% [markdown]
# ## BIOMASS_CANOPY

# %%
dset['BIOMASS_CANOPY'].plot(aspect=3, size=6)

# %% [markdown]
# ## BIOMASS_UNDERSTORY

# %%
dset['BIOMASS_UNDERSTORY'].plot(aspect=3, size=6)

# %% [markdown]
# ## CANOPY_AREA_BY_AGE

# %%
dset['CANOPY_AREA_BY_AGE'].plot(aspect=3, size=6, col='fates_levage', col_wrap=1)

# %% [markdown]
# ## CANOPY_HEIGHT_DIST

# %%
dset['CANOPY_HEIGHT_DIST'].plot(aspect=3, size=6, col='fates_levheight', col_wrap=1)

# %% [markdown]
# ## ED_NCOHORTS

# %%
dset['ED_NCOHORTS'].plot(aspect=3, size=6)

# %% [markdown]
# ## ED_NPATCHES

# %%
dset['ED_NPATCHES'].plot(aspect=3, size=6)

# %% [markdown]
# ## ED_balive

# %%
dset['ED_balive'].plot(aspect=3, size=6)

# %% [markdown]
# ## ED_bdead

# %%
dset['ED_bdead'].plot(aspect=3, size=6)

# %% [markdown]
# ## ED_bfineroot

# %%
dset['ED_bfineroot'].plot(aspect=3, size=6)

# %% [markdown]
# ## ED_biomass

# %%
dset['ED_biomass'].plot(aspect=3, size=6)

# %% [markdown]
# ## ED_bleaf

# %%
dset['ED_bleaf'].plot(aspect=3, size=6)

# %% [markdown]
# ## ED_bsapwood

# %%
dset['ED_bsapwood'].plot(aspect=3, size=6)

# %% [markdown]
# ## ED_bstore

# %%
dset['ED_bstore'].plot(aspect=3, size=6)

# %% [markdown]
# ## PFTbiomass

# %%
dset['PFTbiomass'].plot(aspect=3, size=6, col='fates_levpft', col_wrap=1)

# %% [markdown]
# ## PFTleafbiomass

# %%
dset['PFTleafbiomass'].plot(aspect=3, size=6, col='fates_levpft', col_wrap=1)

# %% [markdown]
# ## PFTnindivs

# %%
dset['PFTnindivs'].plot(aspect=3, size=6, col='fates_levpft', col_wrap=1)

# %% [markdown]
# ## PFTstorebiomass

# %%
dset['PFTstorebiomass'].plot(aspect=3, size=6, col='fates_levpft', col_wrap=1)

# %% [markdown]
# ## MORTALITY

# %%
dset['MORTALITY'].plot(aspect=3, size=6, col='fates_levpft', col_wrap=1)

# %% [markdown]
# ## RECRUITMENT

# %%
dset['RECRUITMENT'].plot(aspect=3, size=6, col='fates_levpft', col_wrap=1)

# %% [markdown]
# ## SEEDS_IN_EXTERN_ELEM

# %%
dset['SEEDS_IN_EXTERN_ELEM'].plot(aspect=3, size=6)

# %% [markdown]
# ## SEEDS_IN_LOCAL_ELEM

# %%
dset['SEEDS_IN_LOCAL_ELEM'].plot(aspect=3, size=6)
